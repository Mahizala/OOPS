# %% [markdown]
# # OOPS- Object Oriented Programming System

# %% [markdown]
# # Theory Questions-

# %% [markdown]
# **Q1.**What is object oriented programming(OOP)?
#
# -->Object-oriented programming (OOP) is a computer programming technique that organizes software around objects, rather than logic and functions. In OOP, objects are created from templates called classes, which define the properties and behaviors of the objects.

# %% [markdown]
# **Q2.**What is class in OOP?
#
# -->In object-oriented programming (OOP), a class is a blueprint or template for creating objects. It defines the structure and behavior of a specific type of object, including its attributes (data members or variables) and methods (member functions).

# %% [markdown]
#  **Q3.**What is object in OOP?
#
#  -->In OOP, an object is a concrete instance of a class. Imagine a class as a blueprint or a template that defines the structure and behavior of a particular type of entity. An object, then, is a specific entity created from that blueprint. Each object possesses its own unique set of attributes (characteristics like color, size, etc.) and can perform actions defined by its class's methods (functions like starting, moving, etc.)

# %% [markdown]
# **Q4.**What is the difference between abstruction and encapsulation?
#
# -->Abstraction:
#
# Focus: Simplifying complex systems by hiding unnecessary details and presenting only the essential features.
# Mechanism:
# Defining interfaces or abstract classes that specify the functionality without revealing the underlying implementation.
# Focusing on "what" an object does rather than "how" it does it.
#
# Encapsulation:
#
# Focus: Bundling data (attributes) and methods (functions) that operate on that data within a single unit (like a class) and controlling access to them.
# Mechanism:
# Using access modifiers (like public, private, protected) to control visibility and prevent unauthorized access or modification of data.
# Data hiding: Protecting the internal state of an object from external interference.
#
# Hence, Abstraction deals with simplifying the interface and hiding complexity.
# Encapsulation deals with protecting data and controlling access to it.

# %% [markdown]
# **Q5.**What are dunder methods in python?
#
# -->In Python, dunder methods (short for "double-underscore methods") are special methods that begin and end with double underscores (e.g., __init__, __str__, __add__). These methods provide a way to customize the behavior of objects in specific ways.

# %% [markdown]
# **Q6.**Explain the concept of inheritance in OOPS.
#
# -->Inheritance is a fundamental principle in OOP that allows you to create new classes (called subclasses or derived classes) from existing ones (called superclasses or base classes). This establishes an "is-a" relationship between the classes. For instance, if you have a class Animal, you could create subclasses like Dog, Cat, and Bird, as these are all types of animals.

# %% [markdown]
# **Q7.**What is Polymorphism in OOP?
#
# -->Polymorphism is a fundamental concept in Object-Oriented Programming (OOP) that allows objects of different classes to be treated as objects of a common type. In simpler terms, it means "many forms."
#
# Key Concepts:
#
# Method Overriding: Subclasses can provide their own specific implementations of methods defined in their superclass. This allows objects of different classes to respond differently to the same method call.
# Interface Implementation: Interfaces define a set of methods that classes must implement. Different classes can implement the same interface in their own unique ways.

# %% [markdown]
# **Q8.**How is encapsulation achieved in python?
#
# -->Encapsulation in Python involves bundling data (attributes) and methods that operate on the data within a class. It restricts direct access to some components, protecting data integrity. This is achieved through:
#
# Name Mangling: Prefixing attributes with __ (e.g., __value) makes them "private," hindering direct access.
#
# Getter/Setter Methods: Controlled access to attributes via methods like get_value() and set_value().
#
# Convention: Using a single underscore (_) prefix to suggest "protected" status (not strictly enforced).
#
# Encapsulation enhances data protection, improves code maintainability, and promotes modularity.

# %% [markdown]
# **Q9.**What is constructor in python?
#
# -->In Python, a constructor is a special method named __init__ that is automatically invoked when an object of a class is created. Its primary function is to initialize the object's attributes with initial values. The __init__ method typically takes at least one parameter, self, which refers to the instance of the class being created. Additional parameters can be passed to provide initial values for the object's attributes. This allows you to set up the object with its initial state, ensuring it's ready for use upon creation. Constructors are essential for proper object initialization and play a crucial role in the object-oriented programming paradigm.

# %% [markdown]
# **Q10.**What are class and static methods in python?
#
# -->In Python, a class acts as a blueprint for creating objects, defining their attributes (variables) and methods (functions). Each object created from a class is an instance of that class. Static methods, on the other hand, are associated with the class itself rather than with specific objects. They are declared using the @staticmethod decorator and do not have access to the self parameter, which represents the instance. Static methods are often used for utility functions that don't rely on the object's state, such as mathematical calculations or general helper functions. This distinction between instance methods and static methods provides flexibility in how you organize and use methods within your Python classes.

# %% [markdown]
# **Q11.**What is method overloading in python?
#
#  -->Python doesn't directly support method overloading in the traditional sense where methods with the same name but different parameter types are distinguished. This is due to Python's dynamic typing. However, you can achieve similar behavior using workarounds like default arguments, which allow you to define methods with optional parameters, and variable-length arguments (*args and **kwargs), which enable you to pass an arbitrary number of arguments to a single method. Additionally, type hints can improve code readability by indicating the expected types of arguments and return values, although they don't enforce type checking at runtime. While not true method overloading, these techniques provide flexibility in how you define and call methods in Python.

# %% [markdown]
# **Q12.**What is method overriding in python?
#
# -->Method overriding in Python is a key principle of object-oriented programming where a subclass provides its own unique implementation for a method that is already defined in its parent class. This is achieved by defining a method in the child class with the same name and parameters as the method in the parent class. While the method signature remains the same, the child class method provides its own specific behavior. This mechanism allows objects of different classes to be treated as objects of a common type, enabling polymorphism. Method overriding enhances code reusability, flexibility, and adaptability in object-oriented systems by allowing subclasses to customize inherited behavior while maintaining a consistent interface.

# %% [markdown]
# **Q13.**What is property decorator in python?
#
# -->In Python, the @property decorator is used to create "getter" and "setter" methods for class attributes, making them appear and behave like regular attributes while providing more control over how they are accessed and modified.
#
# Essentially, it allows you to define methods that get and set the value of an attribute, but you can access them as if they were simple attributes. This enhances encapsulation and provides a more intuitive way to interact with class attributes.

# %% [markdown]
# **Q14.**Why is polymorphism important in OOP?
#
# -->Polymorphism in OOP is crucial because:
#
# * **Reusability:** It allows code to work with objects of different classes without modification.
# * **Flexibility:** New classes can be added without affecting existing code significantly.
# * **Extensibility:** Systems can be easily extended with new subclasses.
# * **Maintainability:** Polymorphic code is more modular and easier to maintain.
#
# Essentially, polymorphism makes your code more adaptable, flexible, and easier to work with in the long run.

# %% [markdown]
# **Q15.**What is an abstract class in python?
#
# -->In Python, an abstract class is a class that cannot be instantiated directly. It serves as a blueprint or template for other classes, defining a common structure and interface. Abstract classes contain one or more abstract methods, which are declared but have no implementation within the class itself. Subclasses that inherit from an abstract class are obligated to provide concrete implementations for all of the abstract methods. This mechanism enforces a consistent structure and interface across related classes, promoting code reusability, improving design, and reducing the likelihood of errors.

# %% [markdown]
# **Q16.**What are the advantages of OOP in python?
#
# -->OOP in Python brings several advantages:
#
# * **Modularity:** Breaks down complex problems into smaller, manageable units (classes and objects).
# * **Reusability:** Encourages code reuse through inheritance and polymorphism.
# * **Maintainability:** Easier to understand, modify, and extend code due to better organization.
# * **Flexibility:** Adapts well to changing requirements due to its inherent flexibility.
# * **Scalability:** Enables building large and complex systems with manageable complexity.
#
# In essence, OOP in Python promotes cleaner, more efficient, and more maintainable code.

# %% [markdown]
# **Q17.**What is the difference vetween a class variable and an instance variable?
#
# -->Class Variable: Shared among all instances of the class. Defined outside any methods.
#
# Instance Variable: Unique to each instance of the class. Defined within class methods (like __init__).
#
# Essentially, class variables are common to all objects of a class, while instance variables are specific to each individual object.

# %% [markdown]
# **Q18.**What is multiple inheritance in python?
#
# -->Multiple inheritance in Python allows a class to inherit properties from more than one parent class. 1  This enables the child class to inherit features from multiple sources, increasing flexibility and code reusability.

# %% [markdown]
# **Q19.**Explain the purpose of" _ _str_ _ " and  "_ _repr_ _" methods in python?
#
# -->In Python, __str__ and __repr__ are special methods that control how objects are represented as strings. __str__ provides a human-readable string for users, often emphasizing readability and conciseness. __repr__ aims for an unambiguous and potentially recreatable string, primarily intended for developers, debugging, and introspection. By implementing these methods, you can customize how your objects are displayed in various contexts, improving code readability and maintainability.

# %% [markdown]
# **Q20.**What is the significance of 'super()' function in python?
#
# -->In Python, super() is used to call methods of the parent class from within a child class.
#
# Purpose:
#
# Method Overriding: Allows child classes to extend or modify the behavior of methods inherited from the parent class.
# Multiple Inheritance: Simplifies method resolution order in cases of multiple inheritance.
# Usage:
#
# super().__init__() is commonly used in the child class's __init__ method to call the parent class's constructor.
# super() promotes code reusability and helps maintain a clear relationship between parent and child classes.

# %% [markdown]
# **Q21.**What is the significance of '_ _ del _ _' method in python?
#
# -->The `__del__` method in Python is called when an object is about to be garbage collected. It allows for cleanup actions like closing files or releasing resources before the object is destroyed.

# %% [markdown]
# **Q22.**What is the difference between the @staticmethod and @classmethod in python?
#
# -->* **@staticmethod:**
#     * No access to `self` (instance) or `cls` (class).
#     * Essentially a regular function within a class for organizational purposes.
#
# * **@classmethod:**
#     * Receives the class itself (`cls`) as the first argument.
#     * Can access and modify class-level attributes.
#
# In essence, `@classmethod` has access to the class itself, while `@staticmethod` is independent of both the class and its instances.

# %% [markdown]
# **Q23.**How does polymorphism work in python with inheritance?
#
# -->In Python, polymorphism with inheritance allows child classes to override methods from their parent class, enabling objects of different classes to be treated uniformly. This is achieved by defining a common interface (methods) in the parent class and then providing specific implementations for these methods in each child class.

# %% [markdown]
# **Q24.**What is method chaining in python?
#
# -->In Python, method chaining allows you to call multiple methods on an object in a single line, making the code more concise and elegant.
#
# Examples:
#
# 1.my_string.lower() converts the string to lowercase.
#
# 2.lower().strip() removes leading and trailing whitespace.
#
# 3.strip().replace(" ", "_") replaces spaces with underscores.

# %% [markdown]
# **Q25.**What is purpose of the '_ _ call _ _' method in python?
#
# -->The `__call__` method in Python allows you to make instances of a class callable, meaning you can treat them as functions. By defining the `__call__` method within a class, you can customize how objects of that class are invoked using the function call syntax (e.g., `my_object()`). This enables you to create flexible and expressive objects that can be used in various ways, such as representing functions, performing operations on demand, or implementing custom behaviors for object invocation.

# %% [markdown]
# # Practical Questions-

# %% [markdown]
# **Q1.**Create a parent class animal with a method speak() that prints a generic message. Create a child class dog that overrides the speak() method to print "Bark!".

# %%
class Animal():
  def speak(self):
    print("Animal sound")

class Dog(Animal):
  def speak(self):
    print("Bark!")

my_dog= Dog()
my_dog.speak()
# Out:
# Bark!

# %% [markdown]
# **Q2.**Write a program to create an abstract class shape with a method area(). Derive classess circle and rectangle from it and implement the area() method in both.

# %%
from abc import abstractmethod

class Shape():
  @abstractmethod
  def area(self):
    print("Shape area")

class Circle(Shape):
  def area(self,radius):
    print("area of cirlce is r**2.",radius**2)

class Rectangle(Shape):
  def area(self,length,breadth):
    print("area of rectangle is length*breath.",length*breadth)

my_shape= Shape()

my_circle= Circle()
my_circle.area(25)

my_rectangle= Rectangle()
my_rectangle.area(10,30)
# Out:
# area of cirlce is r**2. 625
# area of rectangle is length*breath. 300

# %% [markdown]
# **Q3.**Implement a multi-level inheritance scenerio where a class vehicle has an attribute type. Derive a class Car anf further derive a class ElectricCar that adds to battery atrribute.

# %%
class vehicle():
  def info(self):
    print("This is a vehicle")

class car(vehicle):
  def car_info(self,name):
    print("car name is:",name)

class ElectricCar(car):
  def battery(self):
    print("This is an electric car.")

my_vehicle= vehicle()
my_vehicle.info()

my_car= car()
my_car.car_info("Tesla model S.")

my_electric_car= ElectricCar()
my_electric_car.battery()
# Out:
# This is a vehicle
# car name is: Tesla model S.
# This is an electric car.

# %% [markdown]
# **Q.4.**Implement a multi-level inheritance scenerio where a class vehicle has an attribute type. Derive a class Car anf further derive a class ElectricCar that adds to battery atrribute.

# %%
class vehicle():
  def info(self):
    print("This is a vehicle")

class car(vehicle):
  def car_info(self,name):
    print("car name is:",name)

class ElectricCar(car):
  def battery(self):
    print("This is an electric car.")

my_vehicle= vehicle()
my_vehicle.info()

my_car= car()
my_car.car_info("Tesla model S.")

my_electric_car= ElectricCar()
my_electric_car.battery()
# Out:
# This is a vehicle
# car name is: Tesla model S.
# This is an electric car.

# %% [markdown]
# **Q5.**Write a program to demonstrate encapsulation by creating a class BankAccount with private attributes balance and methods to deposit, withdraw and check balance.

# %%
class BankAccount:
    def __init__(self, initial_balance):
        self.__balance = initial_balance  # Encapsulated attribute

    def deposit(self, amount):
        if amount > 0:
            self.__balance += amount
            print(f"Deposited {amount}. New balance: {self.__balance}")
        else:
            print("Invalid deposit amount.")

    def withdraw(self, amount):
        if 0 < amount <= self.__balance:
            self.__balance -= amount
            print(f"Withdrew {amount}. New balance: {self.__balance}")
        else:
            print("Insufficient funds or invalid withdrawal amount.")

    def get_balance(self):
        return self.__balance

# Create a bank account object
account = BankAccount(1000)

# Deposit money
account.deposit(500)

# Withdraw money
account.withdraw(200)

# Check the current balance
print("Current balance:", account.get_balance())

# %% [markdown]
# **Q6.**Demonstrate runtime polymorphism using a method play() in a base class Instrument. Derive classes Guitar and Piano thay implement their own version of play.

# %%
class Instrument:
    def play(self):
        print("Playing instrument")

class Guitar(Instrument):
    def play(self):
        print("Playing guitar")

class Piano(Instrument):
    def play(self):
        print("Playing piano")

def main():
    instruments = [Guitar(), Piano()]
    for instrument in instruments:
        instrument.play()

if __name__ == "__main__":
    main()
# Out:
# Playing guitar
# Playing piano

# %% [markdown]
# **Q7.**Create a class MathOperations with a class method add_numbers to add two numbers and a static method subtract_numbers to subtract two numbers.

# %%
class MathOperations:
    @classmethod
    def add_numbers(cls, a, b):
        return a + b

    @staticmethod
    def subtract_numbers(a, b):
        return a - b

print(MathOperations.add_numbers(31,12))
print(MathOperations.subtract_numbers(12,9))
# Out:
# 43
# 3

# %% [markdown]
# **Q8.** Implement a class person with a class method to count the total number of persons created.

# %%
class Person:
    _count = 0

    def __init__(self, name):
        self.name = name
        Person._count += 1

    @classmethod
    def get_count(cls):
        return cls._count

# Create some Person objects
person1 = Person("rohan")
person2 = Person("ishan")
person3 = Person("jainam")

total_count = Person.get_count()

print(f"Total number of persons created: {total_count}")
# Out:
# Total number of persons created: 3

# %% [markdown]
# **Q9.**Write a class Fraction with attributes numerator and denomenator. override the str method to display the fraction as "numerator/denomenator".

# %%
class Fraction:
    def __init__(self, numerator, denomenator):
        self.numerator = numerator
        self.denomenator = denomenator

    def __str__(self):
        return f"{self.numerator}/{self.denomenator}"

my_fraction= Fraction(12,9)
print(my_fraction)
# Out:
# 12/9

# %% [markdown]
# **Q10.**Demonstrate operator overloading by creating a class vector and overriding the add method to add two numbers.

# %%
class Vector:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def __add__(self, other):
        if isinstance(other, Vector):
            return Vector(self.x + other.x, self.y + other.y)
        return NotImplemented

    def __repr__(self):
        return f"Vector({self.x}, {self.y})"

v1 = Vector(31, 12)
v2 = Vector(12, 9)
result = v1 + v2

print(result)
# Out:
# Vector(43, 21)

# %% [markdown]
# **Q11.**Create a class Person with attributes name and age. Add a method greet() that prints "Hello, my name is {name} and I am {age} years old".

# %%
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def greet(self):
        print(f"Hello, my name is {self.name} and I am {self.age} years old.")

person1=Person("mahi",20)
person2=Person("mann",22)

person1.greet()
person2.greet()
# Out:
# Hello, my name is mahi and I am 20 years old.
# Hello, my name is mann and I am 22 years old.

# %% [markdown]
# **Q12.**Implement the class Student with attributes name and grades.Create a method average_grade() to compute the average of grades.

# %%
class Student:
  def __init__(self,name,grades):
    self.name=name
    self.grades=grades


  def average_grades(self):
      return sum(self.grades)/len(self.grades)

student1= Student("bhumi",[40,70,90,60])

print(student1.average_grades())
# Out:
# 65.0

# %% [markdown]
# **Q13.**Create a class Rectangle with methods set_dimensions() to set the dimension and area() to calculate the area.

# %%
class Rectangle:
  def __init__(self,length,breadth):
    self.length=length
    self.breadth=breadth

  def set_dimensions(self):
    self.length=int(input("Enter the length:"))
    self.breadth=int(input("Enter the breadth:"))

  def area(self):
    return self.length*self.breadth

rectangle1= Rectangle(0,0)
rectangle1.set_dimensions()
print(rectangle1.area())
# Out:
# Enter the length:1200
# Enter the breadth:54
# 64800

# %% [markdown]
# **Q14.**Create a class Employee with the method calculate_salary() that computes the salary based on hours worked and hourly rate. Create a derived class Manager that adds a to the salary.

# %%
class Employee:
  def __init__(self,hours_worked,hourly_rate):
    self.hours_worked=hours_worked
    self.hourly_rate=hourly_rate

  def calculate_salary(self):
    return self.hours_worked*self.hourly_rate

class Manager(Employee):
  def __init__(self,hours_worked,hourly_rate,bonus):
    super().__init__(hours_worked,hourly_rate)
    self.bonus=bonus

  def calculate_salary(self):
     return super().calculate_salary() + self.bonus

Total_salary= Manager(15,1000,500)
print(Total_salary.calculate_salary())
# Out:
# 15500

# %% [markdown]
# **Q15.**Create a class Product with attributes name, price and quantity. Implement a method Total_price() that calculates the total price of the product.

# %%
class Product:
  def __init__(self,name,price,quantity):
    self.name=name
    self.price=price
    self.quantity=quantity

  def Total_price(self):
    return self.price*self.quantity

Product1= Product("bag",1650,2)
Product2 = Product("whatch",1130,6)

print(Product1.Total_price())
print(Product2.Total_price())
# Out:
# 3300
# 6780

# %% [markdown]
# **Q16.**Create a class Animal with an abstract method sound().Create two derived classes Cow and Sheep that Implement the sound() method.

# %%
from abc import ABC, abstractmethod

class Animal(ABC):
    @abstractmethod
    def sound(self):
        pass

class Cow(Animal):
    def sound(self):
        return "Moo"

class Sheep(Animal):
    def sound(self):
        return "Baa"

cow = Cow()
print(cow.sound())

sheep = Sheep()
print(sheep.sound())
# Out:
# Moo
# Baa

# %% [markdown]
# **Q17.**Create a class Book with attributes title,author and year_published. Add a method get_book_info() that returns a formatted string with the book details.

# %%
class Book:
  def __init__(self,title,author,year_published):
    self.title=title
    self.author=author
    self.year_published=year_published

  def get_book_info(self):
    return f"Title: {self.title}\nAuthor: {self.author}\nYear Published: {self.year_published}"

book1= Book("The Alchemist","Paulo Coelho",1988)
print(book1.get_book_info())
# Out:
# Title: The Alchemist
# Author: Paulo Coelho
# Year Published: 1988

# %% [markdown]
# **Q18.**Create a class House with attributes address and price.Create a derives class Mansion that adds on attribute number_of _rooms.

# %%
class House:
  def __init__(self,address,price):
    self.address=address
    self.price=price

class Mansion(House):
  def __init__(self,address,price,number_of_rooms):
    super().__init__(address,price)
    self.number_of_rooms=number_of_rooms

Mansion1= Mansion("456 Oak St", 350000, 8)
print(Mansion1.address)
print(Mansion1.price)
print(Mansion1.number_of_rooms)
# Out:
# 456 Oak St
# 350000
# 8
